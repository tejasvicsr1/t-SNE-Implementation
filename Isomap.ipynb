# %%
from Isomap_Implementation.isomap import *
from Helpers.print_help import *

# %%
X, y = load_from_csv('Datasets/mnist_test.csv')

data = run_isomap(X, y)
plot_graph(data, y, 'Isomap', 'MNIST')
