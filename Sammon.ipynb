# %%
from Sammon_Implementation.sammon import *
from Helpers.print_help import *

# %%
X, y = load_from_csv('Datasets/mnist_test.csv')

data = run_sammon(X, y)
plot_graph(data, y, 'Sammon', 'MNIST')
# Out:
# TolFun exceeded: Optimisation terminated
